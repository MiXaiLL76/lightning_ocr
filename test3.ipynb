# %%
from lightning_ocr.models.abinet import ABINetVision

model = ABINetVision.load_from_folder("checkpoints/abinet")

# %%
from PIL import Image

pillow_image = Image.open("/home/mixaill76/text_datasets/data_collection/005-CV/dataset_2_105_1162.jpg").convert("RGB")
pillow_image
# Out:
# <PIL.Image.Image image mode=RGB size=157x73>

# %%
model.predict(pillow_image)
# Out:
# ['423.3']
